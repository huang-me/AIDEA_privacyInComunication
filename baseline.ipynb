# %%
import os
import sys
import numpy as np
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# ## Preprocessing
# * Change input data (ex. train.txt) into CRF model input format (ex. train.data)
#     * CRF model input format (ex. train.data):
#         ```
#         肝 O
#         功 O
#         能 O
#         6 B-med_exam
#         8 I-med_exam
#         ```

# %%
file_path='data/SampleData_deid.txt'

# %%
def loadInputFile(path):
    # store trainingset [contents]
    trainingset = list()
    # store position [article_id, start_pos, end_pos, entity_text, entity_type]
    position = list()
    # store mentions[mention] = ['word', 'type']
    mentions = dict()
    # OPEN INPUT DATA FILE
    with open(file_path, 'r', encoding='utf8') as f:
        file_text=f.read().encode('utf-8').decode('utf-8-sig')
    # SPLIT CONTENTS
    datas=file_text.split('\n\n--------------------\n\n')[:-1]
    # EXTRACT DATA FROM CONTENT
    for data in datas:
        data=data.split('\n')
        content=data[0]
        trainingset.append(content)
        annotations=data[1:]
        for annot in annotations[1:]:
            #annot= article_id, start_pos, end_pos, entity_text, entity_type
            annot=annot.split('\t')
            position.extend(annot)
            mentions[annot[3]]=annot[4]
    
    return trainingset, position, mentions

trainingset, position, mentions=loadInputFile(file_path)

# %%
def CRFFormatData(trainingset, position, path):
    if (os.path.isfile(path)):
        os.remove(path)
    outputfile = open(path, 'a', encoding= 'utf-8')

    # output file lines
    count = 0 # annotation counts in each content
    tagged = list()
    for article_id in range(len(trainingset)):
        trainingset_split = list(trainingset[article_id])
        while '' or ' ' in trainingset_split:
            if '' in trainingset_split:
                trainingset_split.remove('')
            else:
                trainingset_split.remove(' ')
        start_tmp = 0
        for position_idx in range(0,len(position),5):
            if int(position[position_idx]) == article_id:
                count += 1
                if count == 1:
                    start_pos = int(position[position_idx+1])
                    end_pos = int(position[position_idx+2])
                    entity_type=position[position_idx+4]
                    if start_pos == 0:
                        token = list(trainingset[article_id][start_pos:end_pos])
                        whole_token = trainingset[article_id][start_pos:end_pos]
                        for token_idx in range(len(token)):
                            if len(token[token_idx].replace(' ','')) == 0:
                                continue
                            # BIO states
                            if token_idx == 0:
                                label = 'B-'+entity_type
                            else:
                                label = 'I-'+entity_type
                            
                            output_str = token[token_idx] + ' ' + label + '\n'
                            outputfile.write(output_str)

                    else:
                        token = list(trainingset[article_id][0:start_pos])
                        whole_token = trainingset[article_id][0:start_pos]
                        for token_idx in range(len(token)):
                            if len(token[token_idx].replace(' ','')) == 0:
                                continue
                            
                            output_str = token[token_idx] + ' ' + 'O' + '\n'
                            outputfile.write(output_str)

                        token = list(trainingset[article_id][start_pos:end_pos])
                        whole_token = trainingset[article_id][start_pos:end_pos]
                        for token_idx in range(len(token)):
                            if len(token[token_idx].replace(' ','')) == 0:
                                continue
                            # BIO states
                            if token[0] == '':
                                if token_idx == 1:
                                    label = 'B-'+entity_type
                                else:
                                    label = 'I-'+entity_type
                            else:
                                if token_idx == 0:
                                    label = 'B-'+entity_type
                                else:
                                    label = 'I-'+entity_type

                            output_str = token[token_idx] + ' ' + label + '\n'
                            outputfile.write(output_str)

                    start_tmp = end_pos
                else:
                    start_pos = int(position[position_idx+1])
                    end_pos = int(position[position_idx+2])
                    entity_type=position[position_idx+4]
                    if start_pos<start_tmp:
                        continue
                    else:
                        token = list(trainingset[article_id][start_tmp:start_pos])
                        whole_token = trainingset[article_id][start_tmp:start_pos]
                        for token_idx in range(len(token)):
                            if len(token[token_idx].replace(' ','')) == 0:
                                continue
                            output_str = token[token_idx] + ' ' + 'O' + '\n'
                            outputfile.write(output_str)

                    token = list(trainingset[article_id][start_pos:end_pos])
                    whole_token = trainingset[article_id][start_pos:end_pos]
                    for token_idx in range(len(token)):
                        if len(token[token_idx].replace(' ','')) == 0:
                            continue
                        # BIO states
                        if token[0] == '':
                            if token_idx == 1:
                                label = 'B-'+entity_type
                            else:
                                label = 'I-'+entity_type
                        else:
                            if token_idx == 0:
                                label = 'B-'+entity_type
                            else:
                                label = 'I-'+entity_type
                        
                        output_str = token[token_idx] + ' ' + label + '\n'
                        outputfile.write(output_str)
                    start_tmp = end_pos

        token = list(trainingset[article_id][start_tmp:])
        whole_token = trainingset[article_id][start_tmp:]
        for token_idx in range(len(token)):
            if len(token[token_idx].replace(' ','')) == 0:
                continue

            
            output_str = token[token_idx] + ' ' + 'O' + '\n'
            outputfile.write(output_str)

        count = 0
    
        output_str = '\n'
        outputfile.write(output_str)
        ID = trainingset[article_id]

        if article_id%10 == 0:
            print('Total complete articles:', article_id)

    # close output file
    outputfile.close()

data_path='data/sample.data'
CRFFormatData(trainingset, position, data_path)
# Out:
# Total complete articles: 0
# Total complete articles: 10
# Total complete articles: 20

# %% [markdown]
# ## Model Input:
# * input features:
#     * word vector: pretrained traditional chinese word embedding by Word2Vec-CBOW
#
#     (you may try add some other features, ex. pos-tag, word_length, word_position, ...)

# %%
import numpy as np

# %%
# load pretrained word vectors
# get a dict of tokens (key) and their pretrained word vectors (value)
# pretrained word2vec CBOW word vector: https://fgc.stpi.narl.org.tw/activity/videoDetail/4b1141305ddf5522015de5479f4701b1
dim = 0
word_vecs= {}
# open pretrained word vector file
with open('cna.cbow.cwe_p.tar_g.512d.0.txt') as f:
    for line in f:
        tokens = line.strip().split()

        # there 2 integers in the first line: vocabulary_size, word_vector_dim
        if len(tokens) == 2:
            dim = int(tokens[1])
            continue
    
        word = tokens[0] 
        vec = np.array([ float(t) for t in tokens[1:] ])
        word_vecs[word] = vec

# %%
print('vocabulary_size: ',len(word_vecs),' word_vector_dim: ',vec.shape)
# Out:
# vocabulary_size:  158566  word_vector_dim:  (512,)

# %% [markdown]
# ### Here we split data into training dataset and testing dataset,
# however, we'll provide `development data` and `test data` which is real testing dataset.
#
# You should upload prediction on `development data` and `test data` to system, not this splitted testing dataset.

# %%
# load `train.data` and separate into a list of labeled data of each text
# return:
#   data_list: a list of lists of tuples, storing tokens and labels (wrapped in tuple) of each text in `train.data`
#   traindata_list: a list of lists, storing training data_list splitted from data_list
#   testdata_list: a list of lists, storing testing data_list splitted from data_list
from sklearn.model_selection import train_test_split
def Dataset(data_path):
    with open(data_path, 'r', encoding='utf-8') as f:
        data=f.readlines()#.encode('utf-8').decode('utf-8-sig')
    data_list, data_list_tmp = list(), list()
    article_id_list=list()
    idx=0
    for row in data:
        data_tuple = tuple()
        if row == '\n':
            article_id_list.append(idx)
            idx+=1
            data_list.append(data_list_tmp)
            data_list_tmp = []
        else:
            row = row.strip('\n').split(' ')
            data_tuple = (row[0], row[1])
            data_list_tmp.append(data_tuple)
    if len(data_list_tmp) != 0:
        data_list.append(data_list_tmp)
    
    # here we random split data into training dataset and testing dataset
    # but you should take `development data` or `test data` as testing data
    # At that time, you could just delete this line, 
    # and generate data_list of `train data` and data_list of `development/test data` by this function
    traindata_list, testdata_list, traindata_article_id_list, testdata_article_id_list=train_test_split(data_list,
                                                                                                    article_id_list,
                                                                                                    test_size=0.33,
                                                                                                    random_state=42)
    
    return data_list, traindata_list, testdata_list, traindata_article_id_list, testdata_article_id_list 

data_list, traindata_list, testdata_list, traindata_article_id_list, testdata_article_id_list = Dataset(data_path)

# %%
# look up word vectors
# turn each word into its pretrained word vector
# return a list of word vectors corresponding to each token in train.data
def Word2Vector(data_list, embedding_dict):
    embedding_list = list()

    # No Match Word (unknown word) Vector in Embedding
    unk_vector=np.random.rand(*(list(embedding_dict.values())[0].shape))

    for idx_list in range(len(data_list)):
        embedding_list_tmp = list()
        for idx_tuple in range(len(data_list[idx_list])):
            key = data_list[idx_list][idx_tuple][0] # token

            if key in embedding_dict:
                value = embedding_dict[key]
            else:
                value = unk_vector
            embedding_list_tmp.append(value)
        embedding_list.append(embedding_list_tmp)
    return embedding_list

# %%
# input features: pretrained word vectors of each token
# return a list of feature dicts, each feature dict corresponding to each token
def Feature(embed_list):
    feature_list = list()
    for idx_list in range(len(embed_list)):
        feature_list_tmp = list()
        for idx_tuple in range(len(embed_list[idx_list])):
            feature_dict = dict()
            for idx_vec in range(len(embed_list[idx_list][idx_tuple])):
                feature_dict['dim_' + str(idx_vec+1)] = embed_list[idx_list][idx_tuple][idx_vec]
            feature_list_tmp.append(feature_dict)
        feature_list.append(feature_list_tmp)
    return feature_list

# %%
# get the labels of each tokens in train.data
# return a list of lists of labels
def Preprocess(data_list):
    label_list = list()
    for idx_list in range(len(data_list)):
        label_list_tmp = list()
        for idx_tuple in range(len(data_list[idx_list])):
            label_list_tmp.append(data_list[idx_list][idx_tuple][1])
        label_list.append(label_list_tmp)
    return label_list

# %% [markdown]
# ## NER model
# ### CRF (Conditional Random Field model)
# * Using `sklearn-crfsuite` API
#
#     (you may try `CRF++`, `python-crfsuite`, `pytorch-crfsuite`(neural network version))

# %%
import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics
from sklearn_crfsuite.metrics import flat_classification_report

# %%
def CRF(x_train, y_train, x_test, y_test):
    crf = sklearn_crfsuite.CRF(
        algorithm='lbfgs',
        c1=0.1,
        c2=0.1,
        max_iterations=100,
        all_possible_transitions=True
    )
    crf.fit(x_train, y_train)
    # print(crf)
    y_pred = crf.predict(x_test)
    y_pred_mar = crf.predict_marginals(x_test)

    # print(y_pred_mar)

    labels = list(crf.classes_)
    labels.remove('O')
    f1score = metrics.flat_f1_score(y_test, y_pred, average='weighted', labels=labels)
    sorted_labels = sorted(labels,key=lambda name: (name[1:], name[0])) # group B and I results
    print(flat_classification_report(y_test, y_pred, labels=sorted_labels, digits=3))
    return y_pred, y_pred_mar, f1score, crf

# %% [markdown]
# ## Training

# %%
# Load Word Embedding
trainembed_list = Word2Vector(traindata_list, word_vecs)
testembed_list = Word2Vector(testdata_list, word_vecs)

# %%
# CRF - Train Data (Augmentation Data)
x_train = Feature(trainembed_list)
y_train = Preprocess(traindata_list)

# %%
# CRF - Test Data (Golden Standard)
x_test = Feature(testembed_list)
y_test = Preprocess(testdata_list)

# %%
y_pred, y_pred_mar, f1score, model = CRF(x_train, y_train, x_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#   B-location      0.000     0.000     0.000        15
#   I-location      0.000     0.000     0.000        41
#   B-med_exam      0.000     0.000     0.000        33
#   I-med_exam      1.000     0.025     0.049        80
#      B-money      0.400     0.333     0.364        12
#      I-money      0.375     0.171     0.235        35
#       B-name      0.500     0.143     0.222         7
#       I-name      0.333     0.100     0.154        10
#       B-time      0.566     0.387     0.460       111
#       I-time      0.821     0.449     0.580       265
#
#    micro avg      0.677     0.289     0.405       609
#    macro avg      0.399     0.161     0.206       609
# weighted avg      0.632     0.289     0.369       609
# /home/muen/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:67: FutureWarning: Pass labels=['B-location', 'I-location', 'B-med_exam', 'I-med_exam', 'B-money', 'I-money', 'B-name', 'I-name', 'B-time', 'I-time'] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "

# %%
f1score
# Out:
# 0.3685924191044658

# %% [markdown]
# ## Predict

# %%
input_name = 'data/development_1.txt'
def load_file(input_name):
    with open(input_name, 'r') as dt:
        file_text=dt.read().encode('utf-8').decode('utf-8-sig')
    datas=file_text.split('\n\n--------------------\n\n')[:-1]
    contents = []
    for data in datas:
        data = data.split('\n')
        contents.append(data[1])
    return contents
        
contents = load_file(input_name)

# %%
def format_content(contents):
    dta = []
    for article_id in range(len(contents)):
        set_split = list(contents[article_id])
        while '' or ' ' in set_split:
            if '' in set_split:
                set_split.remove('')
            else:
                set_split.remove(' ')
        dta.append(set_split)
    return dta
    
dta = format_content(contents)

# %%
pred_list = Word2Vector(dta, word_vecs)
pred = Feature(pred_list)
y_pred = model.predict(pred)

# %% [markdown]
# ## Output data
# * Change model output into `output.tsv`
# * Only accept this output format uploading to competition system

# %%
output="article_id\tstart_position\tend_position\tentity_text\tentity_type\n"
for test_id in range(len(y_pred)):
    pos=0
    start_pos=None
    end_pos=None
    entity_text=None
    entity_type=None
    for pred_id in range(len(y_pred[test_id])):
        if y_pred[test_id][pred_id][0]=='B':
            start_pos=pos
            entity_type=y_pred[test_id][pred_id][2:]
        elif start_pos is not None and y_pred[test_id][pred_id][0]=='I' and \
                (len(y_pred[test_id])-1==pred_id or y_pred[test_id][pred_id+1][0]=='O'):
            end_pos=pos
            entity_text=''.join([dta[test_id][position] for position in range(start_pos,end_pos+1)])
            line=str(test_id)+'\t'+str(start_pos)+'\t'+str(end_pos+1)+'\t'+entity_text+'\t'+entity_type
            output+=line+'\n'
        pos+=1

# %%
output_path='output.tsv'
with open(output_path,'w',encoding='utf-8') as f:
    f.write(output)

# %%
print(output)
# Out:
# article_id	start_position	end_position	entity_text	entity_type
# 0	2201	2203	3號	time
# 0	2245	2247	三天	time
# 0	2738	2740	林區	name
# 0	3306	3309	3天份	time
# 1	457	459	五月	time
# 1	671	674	三個月	time
# 2	30	32	7號	time
# 2	40	45	上上個禮拜	time
# 2	752	755	一點點	time
# 2	906	908	半顆	time
# 2	918	920	半顆	time
# 2	1096	1098	半年	time
# 2	1114	1116	半年	time
# 2	1118	1120	半年	time
# 2	1147	1150	三個月	time
# 2	1227	1231	兩個禮拜	time
# 2	1464	1467	一點點	time
# 3	84	86	爬樓	time
# 3	150	152	爬樓	time
# 3	253	255	5號	time
# 3	257	259	6號	time
# 3	266	268	6號	time
# 3	279	281	6號	time
# 3	576	580	6月4號	time
# 3	582	584	前年	time
# 3	592	594	前年	time
# 3	915	917	分鐘	time
# 3	1882	1884	去年	time
# 3	1929	1931	四月	time
# 3	1932	1934	五月	time
# 3	2033	2036	8月份	time
# 3	2178	2180	八月	time
# 3	2195	2197	八月	time
# 3	2204	2207	八月份	time
# 3	2230	2233	八月份	time
# 3	3077	3079	半天	time
# 3	3131	3133	明天	time
# 4	10	12	4號	time
# 4	161	164	一點點	time
# 4	187	190	林醫師	name
# 4	354	358	上個禮拜	time
# 4	731	734	林醫師	name
# 4	806	809	林醫師	name
# 4	815	818	林醫師	name
# 4	844	847	林醫師	name
# 4	875	877	4號	time
# 4	880	883	林醫師	name
# 4	958	960	小姐	name
# 4	1606	1609	林醫師	name
# 4	1620	1623	林醫師	name
# 4	1665	1668	林醫師	name
# 4	1811	1814	林醫師	name
# 4	1960	1963	三個月	time
# 4	1967	1970	三個月	time
# 4	1974	1977	三個月	time
# 4	1979	1982	三個月	time
# 4	1988	1991	三個月	time
# 5	88	90	八點	time
# 5	863	866	6公分	med_exam
# 5	1919	1924	上午，禮拜	time
# 5	1927	1929	上午	time
# 5	2437	2441	6月6號	time
# 5	2476	2478	兩點	time
# 5	2486	2488	早點	time
# 6	28	32	上個禮拜	time
# 6	86	88	前年	time
# 6	158	162	今年5月	time
# 6	376	380	7月4號	time
# 6	802	805	三四天	time
# 6	822	825	三四天	time
# 6	829	832	三四天	time
# 6	895	899	兩個禮拜	time
# 6	1091	1093	小姐	name
# 6	1625	1627	櫻木	location
# 7	717	719	三百	money
# 7	889	892	三個月	time
# 7	910	913	三個月	time
# 7	1038	1041	三個月	time
# 7	1045	1048	三個月	time
# 8	215	218	黃醫師	name
# 8	262	265	黃醫師	name
# 8	533	536	黃醫師	name
# 8	685	689	兩個禮拜	time
# 8	764	767	黃醫師	name
# 9	35	37	五月	time
# 9	35	432	五月的時候抽血，下次來就大概要，要檢查了。民眾：對對對對對，這次就是，還是一樣就是拿那個。醫師：拿一個月。民眾：嘿，拿一個月，啊然後下一次就，就要檢查。護理師：他問說是緊急的嗎？醫師：緊急的，對。護理師：緊急的吼。護理師：他會寫很多欸，他現在開始。醫師：蛤？他是感染。護理師：感染。醫師：骨髓炎感染這樣子，那我們下次剛好也要做年度的檢查。民眾：嗯。醫師：一些像Ｂ肝啊、Ｃ肝啊，還有肝功能啊、尿酸、三高等等。民眾：ＯＫ，好。醫師：檢查就一起做一做這樣子。民眾：好。護理師：問一下ｓｕｂｔａｔｉｏｎ可以選嗎？治療前計畫。醫師：可以，可以，好。那我們下次回診的時候9月，可能假如趕得及的話，有時候流感就可以順便打一打。民眾：哦，好。醫師：嘿，你就看那個公告。民眾：好，ＯＫ，ＯＫ。醫師：我記得你好像每年都有打這樣子。民眾：對對對，每年你都會叫我打。醫師：好，啊血壓、心跳73公斤記一下，那你身高幾公分	time
# 10	241	245	兩個禮拜	time
# 10	262	266	四個禮拜	time
# 10	310	312	昂貴	time
# 10	472	476	四個禮拜	time
# 10	537	541	十月六號	time
# 11	26	29	上禮拜	time
# 11	82	85	一份資	time
# 11	132	135	林醫師	name
# 11	143	146	林醫師	name
# 11	154	156	紐約	location
# 11	174	176	紐約	location
# 11	210	213	林醫師	name
# 11	313	316	林醫師	name
# 11	455	458	林醫師	name
# 11	513	516	林醫師	name
# 11	592	594	兩年	time
# 11	676	678	紐約	location
# 11	729	732	三個月	time
# 11	763	766	四個月	time
# 11	817	819	半顆	time
# 11	829	831	半顆	time
# 11	880	882	半顆	time
# 11	930	933	林醫師	name
# 11	1065	1067	半顆	time
# 11	1094	1099	林醫師6月	name
# 11	1153	1156	兩個月	time
# 11	1179	1182	兩個月	time
# 11	1184	1186	前天	time
# 11	1196	1198	前天	time
# 11	1233	1236	兩個月	time
# 11	1238	1241	兩個月	time
# 11	1273	1276	兩個月	time
# 11	1353	1355	紐約	location
# 11	1358	1360	紐約	location
# 11	1416	1419	兩個月	time
# 11	1470	1472	紐約	location
# 11	1636	1638	後年	time
# 11	1647	1649	兩年	time
# 11	1653	1655	後年	time
# 11	1662	1664	後年	time
# 11	1869	1872	林醫師	name
# 11	1888	1890	去年	time
# 11	2029	2032	林醫師	name
# 11	2152	2154	7號	time
# 12	410	412	6號	time
# 13	48	52	9月2號	time
# 13	412	415	欸年底	time
# 13	432	435	，年底	time
# 13	493	496	0月底	time
# 14	137	139	三天	time
# 14	1136	1140	前兩個月	time
# 14	1182	1184	1號	time
# 14	1312	1315	一點點	time
# 14	1388	1390	0號	time
# 16	203	207	三個禮拜	time
# 16	218	222	六個禮拜	time
# 16	235	239	六個禮拜	time
# 16	257	261	六個禮拜	time
# 16	424	427	三個月	time
# 16	447	449	兩年	time
# 17	1567	1569	明天	time
# 17	1585	1587	後天	time
# 17	1593	1595	明天	time
# 17	1604	1606	明天	time
# 17	1611	1616	今天禮拜天	time
# 17	1621	1626	今天禮拜天	time
# 17	1692	1694	小花	name
# 17	2034	2036	五月	time
# 17	2038	2041	五月份	time
# 17	2062	2065	六月份	time
# 17	2265	2267	清楚	name
# 17	2344	2346	五月	time
# 17	2385	2387	清楚	name
# 17	2507	2509	三天	time
# 18	21	23	五月	time
# 18	429	432	三個月	time
# 18	485	487	半年	time
# 19	53	55	五次	time
# 19	498	500	平衡	location
# 19	821	823	叔叔	name
# 19	832	834	叔叔	name
# 19	1812	1814	五次	time
# 19	2090	2092	四百	money
# 19	3012	3015	在陽明	time
# 19	3081	3084	在陽明	time
# 19	3093	3095	陽明	name
# 19	3836	3839	去陽明	time
# 19	3868	3871	去陽明	time
# 19	4040	4043	五顆星	time
# 19	4098	4104	八天至十四天	time
# 19	5298	5300	叔叔	name
# 20	1011	1013	兩年	time
# 20	1307	1313	三個月三個月	time
# 20	1314	1317	三個月	time
# 20	2147	2149	三天	time
# 20	3013	3016	三個月	time
# 20	4646	4650	8月2號	time
# 20	4662	4665	0號。	time
# 21	209	211	一號	time
# 21	238	240	零號	time
# 21	293	295	一號	time
# 21	330	332	零號	time
# 21	377	379	零號	time
# 21	710	712	清楚	name
# 21	2813	2815	三天	time
# 22	522	525	在陽明	time
# 22	538	540	陽明	name
# 22	743	745	陽明	name
# 22	981	984	四個月	time
# 22	989	992	四個月	time
# 22	1173	1175	承認	name
# 22	2104	2107	三個月	time
# 22	2109	2112	六個月	time
# 22	2355	2357	清楚	name
# 22	2880	2883	寬恕期	time
# 22	3204	3206	清楚	name
# 22	3233	3236	這張單	time
# 22	3241	3243	清楚	name
# 22	3351	3354	三個月	time
# 22	3361	3364	三六九	time
# 22	3366	3369	三六九	time
# 22	3576	3579	三個月	time
# 22	3760	3762	清楚	name
# 22	3832	3834	三份	time
# 23	1244	1246	白明	name
# 24	84	87	五六顆	time
# 24	94	97	五六顆	time
# 24	177	179	三天	time
# 24	267	270	三四天	time
# 24	524	527	五六次	time
# 25	1131	1134	五天忘	time
# 25	1222	1225	三四天	time
# 26	243	245	平日	location
# 26	2339	2342	三個月	time
# 26	2542	2545	三個月	time
# 26	2569	2572	林小姐	name
# 27	264	267	中七天	time
# 27	355	358	上個月	time
# 27	399	401	三天	time
# 27	452	454	三天	time
# 27	518	520	三天	time
# 28	1161	1163	前天	time
# 29	256	259	三個月	time
# 29	380	383	三個月	time
# 29	559	562	三個月	time
# 29	997	999	清楚	name
# 29	1443	1446	三個月	time
# 29	1527	1530	三個月	time
# 29	1872	1875	的月份	time
# 29	2023	2030	一個月7月6號	time
# 29	2325	2328	三個月	time
# 29	2569	2571	兩份	time
# 30	258	261	三天忘	time
# 30	444	451	今天禮拜、禮拜	time
# 30	469	472	禮拜日	time
# 30	510	513	禮拜日	time
# 30	525	528	禮拜日	time
# 30	801	805	三四個小	time
# 30	1629	1631	半年	time
# 31	1924	1928	8月3號	time
# 31	2012	2015	三個月	time
# 32	594	596	明天	time
# 32	827	829	八點	time
# 32	862	864	八點	time
# 32	949	951	八點	time
# 32	959	961	三點	time
# 32	1208	1210	小美	name
# 32	1308	1311	三個月	time
# 32	1312	1315	六個月	time
# 32	1348	1351	三個月	time
# 32	1433	1436	三個月	time
# 32	1444	1447	五千塊	money
# 32	1458	1463	四千到五千	money
# 32	1950	1952	五百	money
# 32	2198	2201	三個月	time
# 32	2211	2214	三個月	time
# 32	2239	2241	半年	time
# 32	2312	2315	三個月	time
# 32	2408	2411	三個月	time
# 32	2668	2671	三個月	time
# 33	881	885	0月7號	time
# 34	437	439	五年	time
# 34	513	515	半年	time
# 34	667	672	一點點小小	time
# 34	724	726	半年	time
# 34	732	734	半年	time
# 34	772	775	五個月	time
# 34	779	782	五個月	time
# 34	1461	1463	三天	time
# 34	2830	2832	半年	time
# 34	2874	2877	三個月	time
# 34	4152	4154	九十	time
# 34	4156	4158	九十	time
# 34	4505	4507	1號	time
# 35	168	171	陳小姐	name
# 35	221	224	陳小姐	name
# 35	748	750	前曾	time
# 35	781	783	前曾	time
# 35	1863	1865	三天	time
# 35	1913	1916	一點點	time
# 35	2084	2086	間千	money
# 35	2110	2112	兩點	time
# 35	2143	2145	兩點	time
# 35	3251	3254	九十五	time
# 35	3397	3399	半年	time
# 35	3480	3482	半年	time
# 35	3486	3489	三個月	time
# 35	3505	3507	半年	time
# 36	17	20	六點半	time
# 36	28	31	六點半	time
# 36	43	46	七點四	time
# 36	183	186	五六次	time
# 36	291	293	明天	time
# 36	586	590	第七個月	time
# 36	602	604	半年	time
# 36	660	662	四月	time
# 36	678	680	四月	time
# 36	715	717	四月	time
# 36	801	803	早點	time
# 37	1069	1071	4千	money
# 37	1073	1075	5千	money
# 38	141	143	八號	time
# 38	160	164	兩個禮拜	time
# 39	141	144	三個月	time
# 39	770	773	六個月	time
# 39	1717	1720	三個月	time
# 39	2008	2011	六個月	time
# 39	2058	2060	疊單	time

# %% [markdown]
# ## Note
# * You may try `python-crfsuite` to train an neural network for NER tagging optimized by gradient descent back propagation
#     * [Documentation](https://github.com/scrapinghub/python-crfsuite)
# * You may try `CRF++` tool for NER tagging by CRF model
#     * [Documentation](http://taku910.github.io/crfpp/)
#     * Need design feature template
#     * Can only computed in CPU
# * You may try other traditional chinese word embedding (ex. fasttext, bert, ...) for input features
# * You may try add other features for NER model, ex. POS-tag, word_length, word_position, ...
# * You should upload the prediction output on `development data` or `test data` provided later to the competition system. Note don't upload prediction output on the splitted testing dataset like this baseline example.

# %% [markdown]
# -----------------------------------------------------
